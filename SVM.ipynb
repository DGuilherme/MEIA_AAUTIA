# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/MEIA_AAUTIA/blob/master/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teorica de SVM
#
# Muito bom para classificaçao e regressão .
#
# ![image.png](data:image/png;base64,...)
#
# é sempre necessário comparar hyper planos com os vetores de suporte (A,B)
#
# ## Como identificar o melhor hyper plane
#
# Maximizar as distancias mas antes de fazer isto temos de garantir que o processo de classificaçao é bemfeito.
#
# ![image.png](data:image/png;base64,...)
# Como no caos da segundafigura
#
# embora a distancia de b seja maior o a é quem classifica melhor
#
# + identificar ainda outliers
#
# ### Nem sempre conseguimos definir uma reta que separa os dados
# por isso é necessario adicionar novas caracteristicas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Estes algoritmos usam o kernel
# ha 3 tipos
# + linear - Multiplica os pares de coordenadas de cada registo
# + polinomial - eleva a d que é um parametreo que é especificado manualmente.
# + Radial basis funcion kernel - mapeia as informaçoes para um espaço de dados d e infinitas dimensoes. O do gamma 0-1 quanot mais ajustado aos casos de treino temos uma situaçao ovefiting

# %% [markdown]
# KNN - desvantagens
# é preciso os dados todos
# esta dependente dos vizinhos
#
#
# Funçao do svm - maximizar a margem
# como é que o svm toma uma decisao nos vetores de suporte
